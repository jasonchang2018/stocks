# %% [markdown]
# # Goal

# %% [markdown]
# Overarching loadData function:
#
# 1. Initial upload.
#     1. Create sheet.
#     2. Input data.
# 2. Refresh --
#     1. Query the latest date.
#     2. Use this date in the API call.
#     3. Add rows in asc order into the respective sheet.
#     4. How to make this vectorized???

# %% [markdown]
# # Import Packages

# %%
options(warn = -1) # options(warn = 0)

# %%
check.packages = function(pkg) {
    new.pkg = pkg[!(pkg %in% installed.packages()[, "Package"])]
    if (length(new.pkg)) 
        install.packages(new.pkg, dependencies = TRUE)
    sapply(pkg, require, character.only = TRUE)
}

# %%
check.packages(
    c(
        ## Procurement & Querying
        'RPostgreSQL',
        'httr',
        'jsonlite',
        
        ## Storing
        'googlesheets',
        
        ## Cleaning & Processing
        'dplyr',
        'lubridate',
        'stringr',
        
        ## Visualizing
        'ggplot2'
    )
)
# Out:
#  RPostgreSQL         httr     jsonlite googlesheets        dplyr    lubridate
#         TRUE         TRUE         TRUE         TRUE         TRUE         TRUE
#      stringr      ggplot2
#         TRUE         TRUE

# %% [markdown]
# # Import Data

# %%
## WORLD TRADING DATA


googl.get = GET(
    url = paste(
        'https://www.worldtradingdata.com/api/v1/history?symbol=GOOGL&api_token=',
        Sys.getenv('WORLD_TRADING_DATA_API_KEY'),
        '&date_to=2019-03-29&sort=oldest&output=json'
    ), 
    sep = ''
)
# headers(googl.get)
googl.get$status_code
str(content(googl.get, 'parsed'))
# Out:
# [1] 200
# List of 2
#  $ name   : chr "GOOGL"
#  $ history:List of 3675
#   ..$ 2004-08-19:List of 5
#   .. ..$ open  : chr "50.01"
#   .. ..$ close : chr "50.17"
#   .. ..$ high  : chr "52.03"
#   .. ..$ low   : chr "47.98"
#   .. ..$ volume: chr "22353092"
#   ..$ 2004-08-20:List of 5
#   .. ..$ open  : chr "50.74"
#   .. ..$ close : chr "54.16"
#   .. ..$ high  : chr "54.54"
#   .. ..$ low   : chr "50.25"
#   .. ..$ volume: chr "11429498"
#   ..$ 2004-08-23:List of 5
#   .. ..$ open  : chr "55.42"
#   .. ..$ close : chr "54.70"
#   .. ..$ high  : chr "56.74"
#   .. ..$ low   : chr "54.53"
#   .. ..$ volume: chr "9140244"
#   ..$ 2004-08-24:List of 5
#   .. ..$ open  : chr "55.65"
#   .. ..$ close : chr "52.44"
#   .. ..$ high  : chr "55.80"
#   .. ..$ low   : chr "51.79"
#   .. ..$ volume: chr "7632224"
#   ..$ 2004-08-25:List of 5
#   .. ..$ open  : chr "52.48"
#   .. ..$ close : chr "53.00"
#   .. ..$ high  : chr "54.00"
#   .. ..$ low   : chr "51.94"
#   .. ..$ volume: chr "4599110"
#   ..$ 2004-08-26:List of 5
#   .. ..$ open  : chr "52.56"
#   .. ..$ close : chr "53.96"
#   .. ..$ high  : chr "53.98"
#   .. ..$ low   : chr "52.33"
#   .. ..$ volume: chr "3551168"
#   ..$ 2004-08-27:List of 5
#   .. ..$ open  : chr "54.06"
#   .. ..$ close : chr "53.08"
#   .. ..$ high  : chr "54.31"
#   .. ..$ low   : chr "52.85"
#   .. ..$ volume: chr "3108977"
#   ..$ 2004-08-30:List of 5
#   .. ..$ open  : chr "52.75"
#   .. ..$ close : chr "51.01"
#   .. ..$ high  : chr "52.75"
#   .. ..$ low   : chr "51.01"
#   .. ..$ volume: chr "2601620"
#   ..$ 2004-08-31:List of 5
#   .. ..$ open  : chr "51.86"
#   .. ..$ close : chr "51.19"
#   .. ..$ high  : chr "51.86"
#   .. ..$ low   : chr "51.08"
#   .. ..$ volume: chr "2463427"
#   ..$ 2004-09-01:List of 5
#   .. ..$ open  : chr "51.38"
#   .. ..$ close : chr "50.13"
#   .. ..$ high  : chr "51.49"
#   .. ..$ low   : chr "49.84"
#   .. ..$ volume: chr "4574578"
#   ..$ 2004-09-02:List of 5
#   .. ..$ open  : chr "49.51"
#   .. ..$ close : chr "50.76"
#   .. ..$ high  : chr "51.19"
#   .. ..$ low   : chr "49.47"
#   .. ..$ volume: chr "7567013"
#   ..$ 2004-09-03:List of 5
#   .. ..$ open  : chr "50.14"
#   .. ..$ close : chr "50.01"
#   .. ..$ high  : chr "50.87"
#   .. ..$ low   : chr "49.66"
#   .. ..$ volume: chr "2578705"
#   ..$ 2004-09-07:List of 5
#   .. ..$ open  : chr "50.40"
#   .. ..$ close : chr "50.79"
#   .. ..$ high  : chr "51.00"
#   .. ..$ low   : chr "49.81"
#   .. ..$ volume: chr "2927073"
#   ..$ 2004-09-08:List of 5
#   .. ..$ open  : chr "50.74"
#   .. ..$ close : chr "51.15"
#   .. ..$ high  : chr "51.52"
#   .. ..$ low   : chr "50.25"
#   .. ..$ volume: chr "2495226"
#   ..$ 2004-09-09:List of 5
#   .. ..$ open  : chr "51.02"
#   .. ..$ close : chr "51.16"
#   .. ..$ high  : chr "51.36"
#   .. ..$ low   : chr "50.50"
#   .. ..$ volume: chr "2032853"
#   ..$ 2004-09-10:List of 5
#   .. ..$ open  : chr "50.80"
#   .. ..$ close : chr "52.67"
#   .. ..$ high  : chr "53.28"
#   .. ..$ low   : chr "50.65"
#   .. ..$ volume: chr "4353885"
#   ..$ 2004-09-13:List of 5
#   .. ..$ open  : chr "53.44"
#   .. ..$ close : chr "53.75"
#   .. ..$ high  : chr "54.21"
#   .. ..$ low   : chr "53.23"
#   .. ..$ volume: chr "3927322"
#   ..$ 2004-09-14:List of 5
#   .. ..$ open  : chr "53.84"
#   .. ..$ close : chr "55.75"
#   .. ..$ high  : chr "56.00"
#   .. ..$ low   : chr "53.40"
#   .. ..$ volume: chr "5488357"
#   ..$ 2004-09-15:List of 5
#   .. ..$ open  : chr "55.50"
#   .. ..$ close : chr "56.00"
#   .. ..$ high  : chr "57.12"
#   .. ..$ low   : chr "55.10"
#   .. ..$ volume: chr "5362452"
#   ..$ 2004-09-16:List of 5
#   .. ..$ open  : chr "56.05"
#   .. ..$ close : chr "56.99"
#   .. ..$ high  : chr "57.90"
#   .. ..$ low   : chr "55.83"
#   .. ..$ volume: chr "4637786"
#   ..$ 2004-09-17:List of 5
#   .. ..$ open  : chr "57.01"
#   .. ..$ close : chr "58.75"
#   .. ..$ high  : chr "58.75"
#   .. ..$ low   : chr "56.78"
#   .. ..$ volume: chr "4748627"
#   ..$ 2004-09-20:List of 5
#   .. ..$ open  : chr "58.47"
#   .. ..$ close : chr "59.68"
#   .. ..$ high  : chr "60.80"
#   .. ..$ low   : chr "58.39"
#   .. ..$ volume: chr "5332562"
#   ..$ 2004-09-21:List of 5
#   .. ..$ open  : chr "59.50"
#   .. ..$ close : chr "58.92"
#   .. ..$ high  : chr "60.21"
#   .. ..$ low   : chr "58.76"
#   .. ..$ volume: chr "3617903"
#   ..$ 2004-09-22:List of 5
#   .. ..$ open  : chr "58.41"
#   .. ..$ close : chr "59.19"
#   .. ..$ high  : chr "59.84"
#   .. ..$ low   : chr "58.41"
#   .. ..$ volume: chr "3794393"
#   ..$ 2004-09-23:List of 5
#   .. ..$ open  : chr "59.09"
#   .. ..$ close : chr "60.41"
#   .. ..$ high  : chr "61.32"
#   .. ..$ low   : chr "58.51"
#   .. ..$ volume: chr "4273082"
#   ..$ 2004-09-24:List of 5
#   .. ..$ open  : chr "61.34"
#   .. ..$ close : chr "59.92"
#   .. ..$ high  : chr "62.05"
#   .. ..$ low   : chr "59.88"
#   .. ..$ volume: chr "4566707"
#   ..$ 2004-09-27:List of 5
#   .. ..$ open  : chr "60.44"
#   .. ..$ close : chr "59.13"
#   .. ..$ high  : chr "60.44"
#   .. ..$ low   : chr "58.90"
#   .. ..$ volume: chr "3536818"
#   ..$ 2004-09-28:List of 5
#   .. ..$ open  : chr "60.53"
#   .. ..$ close : chr "63.43"
#   .. ..$ high  : chr "63.70"
#   .. ..$ low   : chr "60.11"
#   .. ..$ volume: chr "8476027"
#   ..$ 2004-09-29:List of 5
#   .. ..$ open  : chr "63.50"
#   .. ..$ close : chr "65.54"
#   .. ..$ high  : chr "67.51"
#   .. ..$ low   : chr "63.12"
#   .. ..$ volume: chr "15274991"
#   ..$ 2004-09-30:List of 5
#   .. ..$ open  : chr "65.11"
#   .. ..$ close : chr "64.80"
#   .. ..$ high  : chr "66.15"
#   .. ..$ low   : chr "64.50"
#   .. ..$ volume: chr "6890125"
#   ..$ 2004-10-01:List of 5
#   .. ..$ open  : chr "65.32"
#   .. ..$ close : chr "66.29"
#   .. ..$ high  : chr "67.12"
#   .. ..$ low   : chr "64.45"
#   .. ..$ volume: chr "7571329"
#   ..$ 2004-10-04:List of 5
#   .. ..$ open  : chr "67.91"
#   .. ..$ close : chr "67.53"
#   .. ..$ high  : chr "68.44"
#   .. ..$ low   : chr "67.02"
#   .. ..$ volume: chr "6541875"
#   ..$ 2004-10-05:List of 5
#   .. ..$ open  : chr "67.70"
#   .. ..$ close : chr "69.19"
#   .. ..$ high  : chr "69.27"
#   .. ..$ low   : chr "66.12"
#   .. ..$ volume: chr "7507251"
#   ..$ 2004-10-06:List of 5
#   .. ..$ open  : chr "69.22"
#   .. ..$ close : chr "68.54"
#   .. ..$ high  : chr "69.22"
#   .. ..$ low   : chr "68.00"
#   .. ..$ volume: chr "6699883"
#   ..$ 2004-10-07:List of 5
#   .. ..$ open  : chr "68.54"
#   .. ..$ close : chr "69.43"
#   .. ..$ high  : chr "69.94"
#   .. ..$ low   : chr "68.28"
#   .. ..$ volume: chr "7066873"
#   ..$ 2004-10-08:List of 5
#   .. ..$ open  : chr "69.75"
#   .. ..$ close : chr "68.86"
#   .. ..$ high  : chr "69.84"
#   .. ..$ low   : chr "68.51"
#   .. ..$ volume: chr "5543874"
#   ..$ 2004-10-11:List of 5
#   .. ..$ open  : chr "69.06"
#   .. ..$ close : chr "67.63"
#   .. ..$ high  : chr "69.43"
#   .. ..$ low   : chr "66.93"
#   .. ..$ volume: chr "5249263"
#   ..$ 2004-10-12:List of 5
#   .. ..$ open  : chr "67.30"
#   .. ..$ close : chr "68.70"
#   .. ..$ high  : chr "68.81"
#   .. ..$ low   : chr "66.70"
#   .. ..$ volume: chr "5920143"
#   ..$ 2004-10-13:List of 5
#   .. ..$ open  : chr "71.66"
#   .. ..$ close : chr "70.45"
#   .. ..$ high  : chr "71.78"
#   .. ..$ low   : chr "70.04"
#   .. ..$ volume: chr "9894833"
#   ..$ 2004-10-14:List of 5
#   .. ..$ open  : chr "70.45"
#   .. ..$ close : chr "71.00"
#   .. ..$ high  : chr "71.19"
#   .. ..$ low   : chr "69.28"
#   .. ..$ volume: chr "5234304"
#   ..$ 2004-10-15:List of 5
#   .. ..$ open  : chr "72.00"
#   .. ..$ close : chr "72.06"
#   .. ..$ high  : chr "72.75"
#   .. ..$ low   : chr "70.97"
#   .. ..$ volume: chr "6604448"
#   ..$ 2004-10-18:List of 5
#   .. ..$ open  : chr "71.60"
#   .. ..$ close : chr "74.58"
#   .. ..$ high  : chr "74.60"
#   .. ..$ low   : chr "70.61"
#   .. ..$ volume: chr "7032780"
#   ..$ 2004-10-19:List of 5
#   .. ..$ open  : chr "75.50"
#   .. ..$ close : chr "73.97"
#   .. ..$ high  : chr "76.20"
#   .. ..$ low   : chr "73.68"
#   .. ..$ volume: chr "9069401"
#   ..$ 2004-10-20:List of 5
#   .. ..$ open  : chr "74.36"
#   .. ..$ close : chr "70.25"
#   .. ..$ high  : chr "74.50"
#   .. ..$ low   : chr "69.80"
#   .. ..$ volume: chr "11389627"
#   ..$ 2004-10-21:List of 5
#   .. ..$ open  : chr "71.99"
#   .. ..$ close : chr "74.69"
#   .. ..$ high  : chr "75.07"
#   .. ..$ low   : chr "70.81"
#   .. ..$ volume: chr "14998000"
#   ..$ 2004-10-22:List of 5
#   .. ..$ open  : chr "85.16"
#   .. ..$ close : chr "86.22"
#   .. ..$ high  : chr "90.09"
#   .. ..$ low   : chr "82.04"
#   .. ..$ volume: chr "36919840"
#   ..$ 2004-10-25:List of 5
#   .. ..$ open  : chr "87.00"
#   .. ..$ close : chr "93.70"
#   .. ..$ high  : chr "97.22"
#   .. ..$ low   : chr "86.28"
#   .. ..$ volume: chr "32775276"
#   ..$ 2004-10-26:List of 5
#   .. ..$ open  : chr "94.93"
#   .. ..$ close : chr "90.90"
#   .. ..$ high  : chr "96.32"
#   .. ..$ low   : chr "90.00"
#   .. ..$ volume: chr "22313860"
#   ..$ 2004-10-27:List of 5
#   .. ..$ open  : chr "91.15"
#   .. ..$ close : chr "92.99"
#   .. ..$ high  : chr "94.76"
#   .. ..$ low   : chr "90.89"
#   .. ..$ volume: chr "13373482"
#   ..$ 2004-10-28:List of 5
#   .. ..$ open  : chr "92.80"
#   .. ..$ close : chr "96.65"
#   .. ..$ high  : chr "97.20"
#   .. ..$ low   : chr "92.80"
#   .. ..$ volume: chr "14856604"
#   ..$ 2004-10-29:List of 5
#   .. ..$ open  : chr "99.18"
#   .. ..$ close : chr "95.32"
#   .. ..$ high  : chr "99.98"
#   .. ..$ low   : chr "95.30"
#   .. ..$ volume: chr "21183466"
#   ..$ 2004-11-01:List of 5
#   .. ..$ open  : chr "96.00"
#   .. ..$ close : chr "98.02"
#   .. ..$ high  : chr "98.84"
#   .. ..$ low   : chr "95.64"
#   .. ..$ volume: chr "12233618"
#   ..$ 2004-11-02:List of 5
#   .. ..$ open  : chr "99.33"
#   .. ..$ close : chr "97.44"
#   .. ..$ high  : chr "99.63"
#   .. ..$ low   : chr "96.67"
#   .. ..$ volume: chr "11365995"
#   ..$ 2004-11-03:List of 5
#   .. ..$ open  : chr "99.75"
#   .. ..$ close : chr "95.84"
#   .. ..$ high  : chr "100.80"
#   .. ..$ low   : chr "95.38"
#   .. ..$ volume: chr "13897606"
#   ..$ 2004-11-04:List of 5
#   .. ..$ open  : chr "94.13"
#   .. ..$ close : chr "92.35"
#   .. ..$ high  : chr "95.20"
#   .. ..$ low   : chr "91.68"
#   .. ..$ volume: chr "14474388"
#   ..$ 2004-11-05:List of 5
#   .. ..$ open  : chr "90.50"
#   .. ..$ close : chr "84.68"
#   .. ..$ high  : chr "91.15"
#   .. ..$ low   : chr "84.28"
#   .. ..$ volume: chr "19852002"
#   ..$ 2004-11-08:List of 5
#   .. ..$ open  : chr "85.47"
#   .. ..$ close : chr "86.28"
#   .. ..$ high  : chr "87.72"
#   .. ..$ low   : chr "84.70"
#   .. ..$ volume: chr "11200077"
#   ..$ 2004-11-09:List of 5
#   .. ..$ open  : chr "86.13"
#   .. ..$ close : chr "84.35"
#   .. ..$ high  : chr "87.60"
#   .. ..$ low   : chr "82.64"
#   .. ..$ volume: chr "11160536"
#   ..$ 2004-11-10:List of 5
#   .. ..$ open  : chr "84.00"
#   .. ..$ close : chr "83.93"
#   .. ..$ high  : chr "86.26"
#   .. ..$ low   : chr "83.17"
#   .. ..$ volume: chr "10651413"
#   ..$ 2004-11-11:List of 5
#   .. ..$ open  : chr "84.57"
#   .. ..$ close : chr "91.51"
#   .. ..$ high  : chr "91.88"
#   .. ..$ low   : chr "83.79"
#   .. ..$ volume: chr "15023209"
#   ..$ 2004-11-12:List of 5
#   .. ..$ open  : chr "92.66"
#   .. ..$ close : chr "91.00"
#   .. ..$ high  : chr "94.90"
#   .. ..$ low   : chr "88.70"
#   .. ..$ volume: chr "16746068"
#   ..$ 2004-11-15:List of 5
#   .. ..$ open  : chr "90.13"
#   .. ..$ close : chr "92.44"
#   .. ..$ high  : chr "94.16"
#   .. ..$ low   : chr "89.38"
#   .. ..$ volume: chr "11901512"
#   ..$ 2004-11-16:List of 5
#   .. ..$ open  : chr "88.75"
#   .. ..$ close : chr "86.27"
#   .. ..$ high  : chr "89.74"
#   .. ..$ low   : chr "85.42"
#   .. ..$ low   : chr "95.51"
#   .. ..$ volume: chr "4148098"
#   ..$ 2004-12-29:List of 5
#   .. ..$ open  : chr "95.89"
#   .. ..$ close : chr "96.45"
#   .. ..$ high  : chr "96.76"
#   .. ..$ low   : chr "95.89"
#   .. ..$ volume: chr "2679281"
#   ..$ 2004-12-30:List of 5
#   .. ..$ open  : chr "96.49"
#   .. ..$ close : chr "98.80"
#   .. ..$ high  : chr "99.12"
#   .. ..$ low   : chr "95.93"
#   .. ..$ volume: chr "5904978"
#   ..$ 2004-12-31:List of 5
#   .. ..$ open  : chr "99.63"
#   .. ..$ close : chr "96.40"
#   .. ..$ high  : chr "99.94"
#   .. ..$ low   : chr "96.28"
#   .. ..$ volume: chr "7677229"
#   ..$ 2005-01-03:List of 5
#   .. ..$ open  : chr "98.70"
#   .. ..$ close : chr "101.36"
#   .. ..$ high  : chr "101.82"
#   .. ..$ low   : chr "97.73"
#   .. ..$ volume: chr "15860692"
#   ..$ 2005-01-04:List of 5
#   .. ..$ open  : chr "100.67"
#   .. ..$ close : chr "97.25"
#   .. ..$ high  : chr "101.47"
#   .. ..$ low   : chr "96.74"
#   .. ..$ volume: chr "13762396"
#   ..$ 2005-01-05:List of 5
#   .. ..$ open  : chr "96.73"
#   .. ..$ close : chr "96.76"
#   .. ..$ high  : chr "98.45"
#   .. ..$ low   : chr "96.12"
#   .. ..$ volume: chr "8239545"
#   ..$ 2005-01-06:List of 5
#   .. ..$ open  : chr "97.63"
#   .. ..$ close : chr "94.28"
#   .. ..$ high  : chr "97.95"
#   .. ..$ low   : chr "93.86"
#   .. ..$ volume: chr "10389803"
#   ..$ 2005-01-07:List of 5
#   .. ..$ open  : chr "94.80"
#   .. ..$ close : chr "96.93"
#   .. ..$ high  : chr "97.13"
#   .. ..$ low   : chr "94.39"
#   .. ..$ volume: chr "9666175"
#   .. [list output truncated]

# %%
googl.hist = content(googl.get, 'parsed')$history

## Convert googl.hist to be a data frame of size R x C = Dates x Attributes

googl = data.frame(
    session = names(googl.hist),
    matrix(
        data = unlist(googl.hist),
        nrow = length(googl.hist),
        byrow = TRUE
    ),
    stringsAsFactors = FALSE
)



## Since all dates contain the same number of attributes, can just pick random date to get attribute names.

colnames(googl) = c(
    'session',
    names(googl.hist$'2004-08-19')
)



## Convert Data Types

googl$session = as.Date(googl$session)
googl$open = as.numeric(googl$open)
googl$close = as.numeric(googl$close)
googl$high = as.numeric(googl$high)
googl$low = as.numeric(googl$low)
googl$volume = as.numeric(googl$volume)



str(googl)
# Out:
# 'data.frame':	3675 obs. of  6 variables:
#  $ session: Date, format: "2004-08-19" "2004-08-20" ...
#  $ open   : num  50 50.7 55.4 55.6 52.5 ...
#  $ close  : num  50.2 54.2 54.7 52.4 53 ...
#  $ high   : num  52 54.5 56.7 55.8 54 ...
#  $ low    : num  48 50.2 54.5 51.8 51.9 ...
#  $ volume : num  22353092 11429498 9140244 7632224 4599110 ...

# %% [markdown]
# # Upsert to Google Sheets

# %%
# Sys.getenv('R_GMAIL_2FAUTH')
# gs_auth()
# gs_user()

# %%
# gs_ls()
# gs_title('stock-database')
# gs_key('1NhW7Itp3aINCP1fHX_whzs_iLa5nkceRRl1xLm5B5fA')
sheet.id = gs_url('https://docs.google.com/spreadsheets/d/1NhW7Itp3aINCP1fHX_whzs_iLa5nkceRRl1xLm5B5fA/edit?usp=sharing')
# Out:
# Sheet-identifying info appears to be a browser URL.
# googlesheets will attempt to extract sheet key from the URL.
# Putative key: 1NhW7Itp3aINCP1fHX_whzs_iLa5nkceRRl1xLm5B5fA
# Sheet successfully identified: "stock-database"

# %%
## RW information about the WS.

# sheet.id %>% gs_gs() %>% gs_ws_new(ws_title = 'amzn')
# sheet.id %>% gs_gs() %>% gs_ws_rename(from = 'appl', to = 'aapl')

sheet.id %>% 
    gs_gs() %>% 
    gs_ws_ls() #title of sheets within workbook
# Out:
# Sheet successfully identified: "stock-database"
# [1] "googl" "aapl"  "amzn"

# %%
## RW information on the WS

sheet.id = sheet.id %>% gs_gs()
sheet.ws = sheet.id %>% gs_ws_ls()

sheet.id %>% gs_read(sheet.ws[1])
sheet.id %>% gs_read(ws = 1)
sheet.id %>% gs_read(ws = 1, range = "A1:A3")
sheet.id %>% gs_read(ws = 1, range = cell_rows(1:2))
sheet.id %>% gs_read(ws = 1, range = cell_cols(1))
# Out:
# Sheet successfully identified: "stock-database"
# Accessing worksheet titled 'googl'.
# Parsed with column specification:
# cols(
#   id = col_double()
# )
#   id
# 1 1
# 2 2
# 3 3
# Accessing worksheet titled 'googl'.
# Parsed with column specification:
# cols(
#   id = col_double()
# )
#   id
# 1 1
# 2 2
# 3 3
# Accessing worksheet titled 'googl'.
# Parsed with column specification:
# cols(
#   id = col_double()
# )
#   id
# 1 1
# 2 2
# Accessing worksheet titled 'googl'.
# Parsed with column specification:
# cols(
#   id = col_double()
# )
#   id
# 1 1
# Accessing worksheet titled 'googl'.
# Parsed with column specification:
# cols(
#   id = col_double()
# )
#   id
# 1 1
# 2 2
# 3 3

# %%
# Out:
# Sheet successfully identified: "stock-database"
# Worksheet "amzn" added to sheet "stock-database".
# Worksheet dimensions: 1000 x 26.
# Sheet successfully identified: "stock-database"
# Error: Worksheet appl not found.
# Traceback:
#
# 1. sheet.id %>% gs_gs() %>% gs_ws_rename(from = "appl", to = "aapl")
# 2. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 3. eval(quote(`_fseq`(`_lhs`)), env, env)
# 4. eval(quote(`_fseq`(`_lhs`)), env, env)
# 5. `_fseq`(`_lhs`)
# 6. freduce(value, `_function_list`)
# 7. withVisible(function_list[[k]](value))
# 8. function_list[[k]](value)
# 9. gs_ws_rename(., from = "appl", to = "aapl")
# 10. ss %>% gs_ws(from, verbose)
# 11. withVisible(eval(quote(`_fseq`(`_lhs`)), env, env))
# 12. eval(quote(`_fseq`(`_lhs`)), env, env)
# 13. eval(quote(`_fseq`(`_lhs`)), env, env)
# 14. `_fseq`(`_lhs`)
# 15. freduce(value, `_function_list`)
# 16. withVisible(function_list[[k]](value))
# 17. function_list[[k]](value)
# 18. gs_ws(., from, verbose)
# 19. spf("Worksheet %s not found.", ws)
# 20. stop(sprintf(...), call. = FALSE)
